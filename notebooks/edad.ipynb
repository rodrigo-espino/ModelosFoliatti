# %%
import seaborn as sns 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/data_general.csv')

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df, x='Edad', hue='Cluster')
plt.title("Distribucion de Edades por Cluster")
# Out:
# Text(0.5, 1.0, 'Distribucion de Edades por Cluster')

# %%
df.groupby('Cluster')[['AVG_BET', 'BET_TOTAL', 'Edad']].mean()
# Out:
#           AVG_BET    BET_TOTAL       Edad
# Cluster
# 0        3.982476   448.618427  65.632834
# 1        4.008627  3070.030710  59.034911
# 2        5.125249   561.700700  43.076730
# 3        3.722259  8575.327435  59.316461
